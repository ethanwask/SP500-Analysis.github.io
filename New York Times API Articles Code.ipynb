# %%
import requests
import json

### GET ARTICLES MATCHING OUR QUERY ###
def get_url(q, begin_date, end_date):
    url = ("https://api.nytimes.com/svc/search/v2/articlesearch.json?q={0}&begin_date={1}&end_date={2}&api-key=GAgkTBB83AC0GwrrTCDTbUxv8R09Dq41".format(q, begin_date, end_date))
    return url

print("Querying NYTimes API...")
r = requests.get(get_url('S&P500', 20220101, 20230228))
print("Status Code returned {0}".format(r.status_code))
print("Data returned: ")
print(r.json()['response']['docs'])
# Out:
# Querying NYTimes API...
# Status Code returned 200
# Data returned:
# ...

# %%
len(r.json()['response']['docs'])
# Out:
# 10

# %%
import pandas as pd
df = pd.json_normalize(r.json()['response']['docs'])

# %%
df
# Out:
#                                             abstract  \
# 0  Revelations about Bill Clinton’s sex-and-lies ...
# 1  The three people were sentenced to life in pri...
# 2  The agency has charged the crypto trading firm...
# 3  Special counsel investigations have become inc...
# 4  The state is taking action against three major...
# 5  Despite some postmodern features, the fighting...
# 6  He argued against affirmative action and the V...
# 7  After months of talks, the activist investor N...
# 8  Two Democrats filed an official complaint abou...
# 9  Extreme opposition to social insurance and the...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2023/01/21/us/politics...
# 1  https://www.nytimes.com/2023/01/20/us/michigan...
# 2  https://www.nytimes.com/2023/01/13/business/de...
# 3  https://www.nytimes.com/2023/01/18/opinion/tru...
# 4  https://www.nytimes.com/2023/01/18/health/insu...
# 5  https://www.nytimes.com/2023/01/16/world/europ...
# ...
